# %%
import os
import pandas as pd

# %%
# Define the base directory containing the trip folders
base_dir = "data"

# %%
# Initialize an empty list to store DataFrames
data_frames = []

# %%
# Define a mapping of inconsistent column names to standard column names
column_mapping = {
    # "starttime": "starttime",
    "started_at": "starttime",
    # "stoptime": "stoptime",
    "ended_at": "stoptime",
    # "start station id": "start station id",
    "start_station_id": "start station id",
    # "start station name": "start station name",
    "start_station_name": "start station name",
    # "start station latitude": "start station latitude",
    "start_lat": "start station latitude",
    # "start station longitude": "start station longitude",
    "start_lng": "start station longitude",
    # "end station id": "end station id",
    "end_station_id": "end station id",
    # "end station name": "end station name",
    "end_station_name": "end station name",
    # "end station latitude": "end station latitude",
    "end_lat": "end station latitude",
    # "end station longitude": "end station longitude",
    "end_lng": "end station longitude",
    # "bikeid": "bikeid",
    "ride_id": "bikeid",
}

# %%
# Walk through the directory structure
for root, dirs, files in os.walk(base_dir):
    # print(root,dirs,files)
    for file in files:
        # Check if the file is a CSV
        if file.endswith(".csv"):
            file_path = os.path.join(root, file)
            # Load the CSV into a DataFrame and append to the list
            try:
                df = pd.read_csv(file_path)
                
                # Standardize column names
                df.rename(columns=column_mapping, inplace=True)

                # Optionally ensure all necessary columns are present
                required_columns = list(column_mapping.values())
                df = df.reindex(columns=required_columns)

                data_frames.append(df)
            except Exception as e:
                print(f"Could not load {file_path}: {e}")
# Out:
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/932235421.py:10: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
# Concatenate all DataFrames into a single DataFrame
if data_frames:
    combined_data = pd.concat(data_frames, ignore_index=True)
    print(f"Loaded {len(data_frames)} CSV files into a single DataFrame.")
else:
    print("No CSV files were found in the specified directory.")
# Out:
# Loaded 128 CSV files into a single DataFrame.

# %%
combined_data.info()

# %%
combined_data.head()
# Out:
#            starttime           stoptime start station id  \
# 0  4/1/2015 00:00:23  4/1/2015 00:04:25              494
# 1  4/1/2015 00:00:52  4/1/2015 00:10:31               82
# 2  4/1/2015 00:01:28  4/1/2015 00:09:33              223
# 3  4/1/2015 00:01:31  4/1/2015 00:20:36              393
# 4  4/1/2015 00:01:36  4/1/2015 00:18:40              212
#
#         start station name  start station latitude  start station longitude  \
# 0          W 26 St & 8 Ave               40.747348               -73.997236
# 1   St James Pl & Pearl St               40.711174               -74.000165
# 2          W 13 St & 7 Ave               40.737815               -73.999947
# 3        E 5 St & Avenue C               40.722992               -73.979955
# 4  W 16 St & The High Line               40.743349               -74.006818
#
#   end station id       end station name  end station latitude  \
# 0            489       10 Ave & W 28 St             40.750664
# 1           2008  Little West St & 1 Pl             40.705693
# 2            445     E 10 St & Avenue A             40.727408
# 3            393      E 5 St & Avenue C             40.722992
# 4            438    St Marks Pl & 1 Ave             40.727791
#
#    end station longitude bikeid
# 0             -74.001768  15510
# 1             -74.016777  15014
# 2             -73.981420  20881
# 3             -73.979955  20295
# 4             -73.985649  19871

# %%
combined_data.tail()
# Out:
#          starttime                  stoptime start station id  \
# 98855109       NaT  2019-06-01 00:04:50.4620             3175
# 98855110       NaT  2019-06-01 00:05:11.1630             2003
# 98855111       NaT  2019-06-01 00:31:58.3920              146
# 98855112       NaT  2019-06-01 00:34:00.1970             3658
# 98855113       NaT  2019-06-01 00:15:59.8680              285
#
#                start station name  start station latitude  \
# 98855109  W 70 St & Amsterdam Ave               40.777480
# 98855110          1 Ave & E 18 St               40.733812
# 98855111     Hudson St & Reade St               40.716250
# 98855112          W 18 St & 9 Ave               40.743534
# 98855113       Broadway & E 14 St               40.734546
#
#           start station longitude end station id       end station name  \
# 98855109               -73.982886            423        W 54 St & 9 Ave
# 98855110               -73.980544            536        1 Ave & E 30 St
# 98855111               -74.009106            422       W 59 St & 10 Ave
# 98855112               -74.003676           2008  Little West St & 1 Pl
# 98855113               -73.990741           3656      E 2 St & Avenue A
#
#           end station latitude  end station longitude bikeid
# 98855109             40.765849             -73.986905  32285
# 98855110             40.741444             -73.975361  33874
# 98855111             40.770513             -73.988038  33395
# 98855112             40.705693             -74.016777  27624
# 98855113             40.723077             -73.985836  32565

# %%
data = combined_data

# %%
# def custom_parser(date_str):
#     from datetime import datetime
#     try:
#         return datetime.strptime(date_str, '%m/%d/%Y %H:%M:%S')  # MM/DD/YYYY
#     except ValueError:
#         try:
#             return datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')  # YYYY-MM-DD
#         except ValueError:
#             return pd.NaT  # Return NaT if parsing fails
def custom_parser(date_str):
    from datetime import datetime
    try:
        # Format: MM/DD/YYYY HH:MM:SS
        return datetime.strptime(date_str, '%m/%d/%Y %H:%M:%S')
    except ValueError:
        try:
            # Format: YYYY-MM-DD HH:MM:SS
            return datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
        except ValueError:
            try:
                # Format: YYYY-MM-DD HH:MM:SS.sssss (microseconds)
                # Strip microseconds before parsing
                trimmed_date_str = date_str.split('.')[0]
                return datetime.strptime(trimmed_date_str, '%Y-%m-%d %H:%M:%S')
            except ValueError:
                return pd.NaT  # Return NaT if parsing fails

# %%
data['starttime'] = data['starttime'].apply(custom_parser)
# data['date'] = data['starttime'].dt.date  # Extract the date only

# %%
x = data.tail()
x['starttime'] = x['stoptime'].apply(custom_parser)
x
# Out:
# /var/folders/4y/v276g2hd4d9f9p1n7dkrz1580000gn/T/ipykernel_44634/4197214540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['starttime'] = x['stoptime'].apply(custom_parser)
#          starttime                  stoptime start station id  \
# 98855109       NaT  2019-06-01 00:04:50.4620             3175
# 98855110       NaT  2019-06-01 00:05:11.1630             2003
# 98855111       NaT  2019-06-01 00:31:58.3920              146
# 98855112       NaT  2019-06-01 00:34:00.1970             3658
# 98855113       NaT  2019-06-01 00:15:59.8680              285
#
#                start station name  start station latitude  \
# 98855109  W 70 St & Amsterdam Ave               40.777480
# 98855110          1 Ave & E 18 St               40.733812
# 98855111     Hudson St & Reade St               40.716250
# 98855112          W 18 St & 9 Ave               40.743534
# 98855113       Broadway & E 14 St               40.734546
#
#           start station longitude end station id       end station name  \
# 98855109               -73.982886            423        W 54 St & 9 Ave
# 98855110               -73.980544            536        1 Ave & E 30 St
# 98855111               -74.009106            422       W 59 St & 10 Ave
# 98855112               -74.003676           2008  Little West St & 1 Pl
# 98855113               -73.990741           3656      E 2 St & Avenue A
#
#           end station latitude  end station longitude bikeid
# 98855109             40.765849             -73.986905  32285
# 98855110             40.741444             -73.975361  33874
# 98855111             40.770513             -73.988038  33395
# 98855112             40.705693             -74.016777  27624
# 98855113             40.723077             -73.985836  32565

# %%
data['starttime'] = pd.to_datetime(data['starttime'])
data['date'] = data['starttime'].dt.date  # Extract the date only

# %%
daily_data = data.groupby('date').size().reset_index(name='trip_count')
daily_data['date'] = pd.to_datetime(daily_data['date'])
daily_data.set_index('date', inplace=True)

# %%
data['day_of_week'] = data['starttime'].dt.dayofweek  # 0 = Monday, 6 = Sunday
data['month'] = data['starttime'].dt.month
data['year'] = data['starttime'].dt.year
data['hour'] = data['starttime'].dt.hour

# %%
data
# Out:
#                    starttime                  stoptime start station id  \
# 0        2015-04-01 00:00:23         4/1/2015 00:04:25              494
# 1        2015-04-01 00:00:52         4/1/2015 00:10:31               82
# 2        2015-04-01 00:01:28         4/1/2015 00:09:33              223
# 3        2015-04-01 00:01:31         4/1/2015 00:20:36              393
# 4        2015-04-01 00:01:36         4/1/2015 00:18:40              212
# ...                      ...                       ...              ...
# 98855109                 NaT  2019-06-01 00:04:50.4620             3175
# 98855110                 NaT  2019-06-01 00:05:11.1630             2003
# 98855111                 NaT  2019-06-01 00:31:58.3920              146
# 98855112                 NaT  2019-06-01 00:34:00.1970             3658
# 98855113                 NaT  2019-06-01 00:15:59.8680              285
#
#                start station name  start station latitude  \
# 0                 W 26 St & 8 Ave               40.747348
# 1          St James Pl & Pearl St               40.711174
# 2                 W 13 St & 7 Ave               40.737815
# 3               E 5 St & Avenue C               40.722992
# 4         W 16 St & The High Line               40.743349
# ...                           ...                     ...
# 98855109  W 70 St & Amsterdam Ave               40.777480
# 98855110          1 Ave & E 18 St               40.733812
# 98855111     Hudson St & Reade St               40.716250
# 98855112          W 18 St & 9 Ave               40.743534
# 98855113       Broadway & E 14 St               40.734546
#
#           start station longitude end station id       end station name  \
# 0                      -73.997236            489       10 Ave & W 28 St
# 1                      -74.000165           2008  Little West St & 1 Pl
# 2                      -73.999947            445     E 10 St & Avenue A
# 3                      -73.979955            393      E 5 St & Avenue C
# 4                      -74.006818            438    St Marks Pl & 1 Ave
# ...                           ...            ...                    ...
# 98855109               -73.982886            423        W 54 St & 9 Ave
# 98855110               -73.980544            536        1 Ave & E 30 St
# 98855111               -74.009106            422       W 59 St & 10 Ave
# 98855112               -74.003676           2008  Little West St & 1 Pl
# 98855113               -73.990741           3656      E 2 St & Avenue A
#
#           end station latitude  end station longitude bikeid        date  \
# 0                    40.750664             -74.001768  15510  2015-04-01
# 1                    40.705693             -74.016777  15014  2015-04-01
# 2                    40.727408             -73.981420  20881  2015-04-01
# 3                    40.722992             -73.979955  20295  2015-04-01
# 4                    40.727791             -73.985649  19871  2015-04-01
# ...                        ...                    ...    ...         ...
# 98855109             40.765849             -73.986905  32285         NaT
# 98855110             40.741444             -73.975361  33874         NaT
# 98855111             40.770513             -73.988038  33395         NaT
# 98855112             40.705693             -74.016777  27624         NaT
# 98855113             40.723077             -73.985836  32565         NaT
#
#           day_of_week  month    year  hour
# 0                 2.0    4.0  2015.0   0.0
# 1                 2.0    4.0  2015.0   0.0
# 2                 2.0    4.0  2015.0   0.0
# 3                 2.0    4.0  2015.0   0.0
# 4                 2.0    4.0  2015.0   0.0
# ...               ...    ...     ...   ...
# 98855109          NaN    NaN     NaN   NaN
# 98855110          NaN    NaN     NaN   NaN
# 98855111          NaN    NaN     NaN   NaN
# 98855112          NaN    NaN     NaN   NaN
# 98855113          NaN    NaN     NaN   NaN
#
# [98855114 rows x 16 columns]

# %%
import matplotlib.pyplot as plt

# Daily trip counts
plt.figure(figsize=(12, 6))
plt.plot(daily_data.index, daily_data['trip_count'], label='Daily Trips')
plt.title('Daily CitiBike Trip Counts (2013–2023)')
plt.xlabel('Date')
plt.ylabel('Number of Trips')
plt.legend()
plt.show()

# %%
# Average trips by day of the week
avg_trips_by_weekday = data.groupby('day_of_week').size()
avg_trips_by_weekday.plot(kind='bar', figsize=(8, 5), title="Average Trips by Day of the Week")
plt.xlabel('Day of the Week (0 = Monday, 6 = Sunday)')
plt.ylabel('Average Number of Trips')
plt.show()

# Monthly trends
monthly_trends = data.groupby('month').size()
monthly_trends.plot(kind='bar', figsize=(8, 5), title="Monthly Trip Counts")
plt.xlabel('Month')
plt.ylabel('Total Number of Trips')
plt.show()

# %%
hourly_trends = data.groupby('hour').size()
hourly_trends.plot(kind='bar', figsize=(10, 5), title="Average Trips by Hour of the Day")
plt.xlabel('Hour of the Day')
plt.ylabel('Average Number of Trips')
plt.show()

# %%
top_stations = data['start station name'].value_counts().head(10)
top_stations.plot(kind='bar', figsize=(10, 5), title="Top 10 Stations by Number of Trips")
plt.xlabel('Station Name')
plt.ylabel('Number of Trips')
plt.show()

# %%
# # Lag features for trip counts (optional for time series)
# daily_data['trip_count_lag1'] = daily_data['trip_count'].shift(1)
# daily_data['trip_count_lag7'] = daily_data['trip_count'].shift(7)
# daily_data['trip_count_rolling7'] = daily_data['trip_count'].rolling(window=7).mean()

# %%
daily_data
# Out:
#             trip_count  day_of_week  month  year  is_weekend
# date
# 2013-06-01       17444            5      6  2013           1
# 2013-06-02       31942            6      6  2013           1
# 2013-06-03       15196            0      6  2013           0
# 2013-06-04       31564            1      6  2013           0
# 2013-06-05       31380            2      6  2013           0
# ...                ...          ...    ...   ...         ...
# 2014-12-27       20494            5     12  2014           1
# 2014-12-28       15804            6     12  2014           1
# 2014-12-29       27098            0     12  2014           0
# 2014-12-30       24392            1     12  2014           0
# 2014-12-31       19478            2     12  2014           0
#
# [579 rows x 5 columns]

# %%
# daily_data = daily_data.drop(["trip_count_rolling7","trip_count_lag7","trip_count_lag1"],axis=1)

# %%
# Add time-based features
daily_data['day_of_week'] = daily_data.index.dayofweek  # 0 = Monday, 6 = Sunday
daily_data['month'] = daily_data.index.month
daily_data['year'] = daily_data.index.year
daily_data['is_weekend'] = (daily_data['day_of_week'] >= 5).astype(int)  # 1 for Saturday/Sunday, 0 otherwise

# %%
# Split data into training (2013–2022) and testing (2023)
train_data = daily_data[daily_data.index.year < 2023]
test_data = daily_data[daily_data.index.year == 2023]
# Out:
# DatetimeIndex(['2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04',
#                '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08',
#                '2013-06-09', '2013-06-10',
#                ...
#                '2014-12-22', '2014-12-23', '2014-12-24', '2014-12-25',
#                '2014-12-26', '2014-12-27', '2014-12-28', '2014-12-29',
#                '2014-12-30', '2014-12-31'],
#               dtype='datetime64[ns]', name='date', length=579, freq=None)

# %%
# Define features and target variable
features = ['day_of_week', 'month', 'is_weekend'] # 'trip_count_lag1', 'trip_count_lag7', 'trip_count_rolling7'
X_train = train_data[features]
y_train = train_data['trip_count']
X_test = test_data[features]
y_test = test_data['trip_count']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Initialize and train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on the test set
predictions = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Visualize predictions vs actual values
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, y_test, label="Actual", alpha=0.7)
plt.plot(test_data.index, predictions, label="Predicted", alpha=0.7)
plt.title("Actual vs Predicted Daily Trip Counts (2023)")
plt.xlabel("Date")
plt.ylabel("Number of Trips")
plt.legend()
plt.show()

# %%
# Exclude COVID-19 period
train_data_no_covid = train_data[
    (train_data.index < '2020-03-01') | (train_data.index > '2021-06-30')
]
